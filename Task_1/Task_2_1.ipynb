# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

#headers = ['Sensor Value','Date','Time']
headers = ['index','url','time_in_seconds','level']

df = pd.read_csv('dataset.csv',names=headers)
print (df)

x = df['time_in_seconds']
y = df['index']

# plot
plt.plot(x,y)

plt.show()
# Out:
#      index                                                url  \
# 0      NaN                                                url
# 1      0.0                     https://west.uni-koblenz.de/en
# 2      1.0            https://west.uni-koblenz.de/en/feed.xml
# 3      2.0            https://west.uni-koblenz.de/en/services
# 4      3.0            https://west.uni-koblenz.de/en/about-us
# 5      4.0            https://west.uni-koblenz.de/en/studying
# 6      5.0                https://west.uni-koblenz.de/en/jobs
# 7      6.0                https://west.uni-koblenz.de/en/news
# 8      7.0            https://west.uni-koblenz.de/en/start-en
# 9      8.0                https://west.uni-koblenz.de/en/jobs
# 10     9.0            https://west.uni-koblenz.de/en/about-us
# 11    10.0            https://west.uni-koblenz.de/en/about-us
# 12    11.0            https://west.uni-koblenz.de/en/start-en
# 13    12.0            https://west.uni-koblenz.de/en/about-us
# ...
